# %% [markdown]
# #Perceptron From Scratch

# %%
#Step 1
X= [0.75, 0.65, 0.80]     #Input features
w= [0.4,0.3,0.5]          #Initial weights
b = -0.2                 #Initial bias
Y = 1                     #Target output
n = 0.01                  #learning Rate

print("Initial Weights:", w)
print("Initial Bias:", b)

# Step 2: Compute Net Input (z = Σ(wi*xi) + b)
z = 0
for i in range(len(X)):
    z += w[i] * X[i]
z += b

print("\nNet Input (z):", z)


# Step 3: Apply Activation Function
if z >= 0:
    y_pred = 1
else:
    y_pred = 0

print("Predicted Output:", y_pred)

#Step4 Calculate error
loss = Y-y_pred
print("Loss:", loss)

#STep5
if loss == 0:
  print("Prediction matches target, No Update required")
else:
  print("Wrong Prediction")

  # Step 6: Update weights
  for i in range(len(w)):
        w[i] = w[i] + n * loss * X[i]

  # Step 7: Update bias
  b = b + n * loss

  # Recalculate net input after learning
  z_new = 0
  for i in range(len(X)):
    z_new = z_new + w[i] * X[i]
  z_new = z_new + b

  print("New net input (z):", z_new)

  if z_new >= 0:
      final_output = 1
  else:
      final_output = 0

  print("Final Prediction:", final_output)


# Step 8: Print updated results
print("\nUpdated Weights:", w)
print("Updated Bias:", b)
# Out:
# Initial Weights: [0.4, 0.3, 0.5]
# Initial Bias: -0.2
#
# Net Input (z): 0.6950000000000001
# Predicted Output: 1
# Loss: 0
# Prediction matches target, No Update required
#
# Updated Weights: [0.4, 0.3, 0.5]
# Updated Bias: -0.2

# %%
#Step 1
X= [0.75, 0.65, 0.80]     #Input features
w= [0.4,0.3,0.5]          #Initial weights
b = -0.9                 #Initial bias
Y = 1                     #Target output
n = 0.01                  #learning Rate

print("Initial Weights:", w)
print("Initial Bias:", b)

# Step 2: Compute Net Input (z = Σ(wi*xi) + b)
z = 0
for i in range(len(X)):
    z += w[i] * X[i]
z += b

print("\nNet Input (z):", z)


# Step 3: Apply Activation Function
if z >= 0:
    y_pred = 1
else:
    y_pred = 0

print("Predicted Output:", y_pred)

#Step4 Calculate error
loss = Y-y_pred
print("Loss:", loss)

#STep5
if loss == 0:
  print("Prediction matches target, No Update required")
else:
  print("Wrong Prediction")

  # Step 6: Update weights
  for i in range(len(w)):
        w[i] = w[i] + n * loss * X[i]

  # Step 7: Update bias
  b = b + n * loss

# Step 8: Print updated results
print("\nUpdated Weights:", w)
print("Updated Bias:", b)

# Recalculate net input after learning
z_new = 0
for i in range(len(X)):
    z_new = z_new + w[i] * X[i]
z_new = z_new + b

print("New net input (z):", z_new)

if z_new >= 0:
    final_output = 1
else:
    final_output = 0

print("Final Prediction:", final_output)
# Out:
# Initial Weights: [0.4, 0.3, 0.5]
# Initial Bias: -0.9
#
# Net Input (z): -0.0050000000000000044
# Predicted Output: 0
# Loss: 1
# Wrong Prediction
#
# Updated Weights: [0.40750000000000003, 0.3065, 0.508]
# Updated Bias: -0.89
# New net input (z): 0.021250000000000102
# Final Prediction: 1

# %%
# Perceptron from scratch
#Given data (X,w,Y,b,n)
#Compute Net input (z)=wixi + b
# Applu activation funcition
# calc error (loss = y-y_pred)
# chk if output match target print result otherwise step3
# weight update desicion
# bias update_abstractmethods
# print results
